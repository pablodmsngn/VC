# %% [markdown]
# Paquetes necesarios

# %%
import cv2  
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Inicializaciones

# %%
#Dimensiones de la imagen a crear
ancho = 300
alto = 200

# %% [markdown]
# Imagen en grises

# %%
#Crea una imagen de un único plano
# Al ser un único plano, se interpreta como nivel de gris (0 negro, 255 blanco)
gris_img = np.zeros((alto,ancho,1), dtype = np.uint8)
#Muestra dimensiones de la imagen creada
print(gris_img.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 #Crea una imagen de un único plano
#       2 # Al ser un único plano, se interpreta como nivel de gris (0 negro, 255 blanco)
# ----> 3 gris_img = np.zeros((alto,ancho,1), dtype = np.uint8)
#       4 #Muestra dimensiones de la imagen creada
#       5 print(gris_img.shape)
#
# NameError: name 'np' is not defined

# %% [markdown]
# Muestra imagen con imshow (OpenCV). Observa que se muestra en ventana independiente

# %%
#Muestra la imagen (negra al inicializarse a 0) con las utilidades de OpenCV en una ventana independiente
cv2.imshow('Imagen', gris_img)

cv2.waitKey(-1) # Se detiene hasta pulsar tecla (>0 milisegundos)
cv2.destroyAllWindows() # Destruye todas las ventanas

# %% [markdown]
# Muestra imagen con matplotlib

# %%
#Muestra la imagen con matplotlib, aparece integrada en el cuaderno
#Es necesario especificar que el mapa de color usado es de grises
plt.imshow(gris_img, cmap='gray') #default: 'viridis'
#plt.imshow(gris_img) #Sin escoger el mapa de colores
plt.show()

#replicar una imagen de gris creando una imagen gris pero con tres planos (RGB)
#img2 = cv2.merge((gris_img,gris_img,gris_img))
#plt.imshow(img2)
#plt.show()

# %% [markdown]
# Imagen con tono de gris aleatorio

# %%
#Crea imagen con un único plano (gris)
gris_img = np.random.randint(255, size=(alto,ancho, 1))
#Muestra dimensiones
print(gris_img.shape)
#Visualiza
plt.imshow(gris_img, cmap='gray') #Visualiza con mapa de color gris
plt.show()
# Out:
# (200, 300, 1)

# %% [markdown]
# Asignamos valor a los píxeles de una zona concreta

# %%
gris_img = np.zeros((alto,ancho,1), dtype = np.uint8)
#Modifica un par de zonas rectangulares de la imagen
gris_img[10:20,0:ancho,0] = 128 #tercer índice especifica un canal (0-2)
#gris_img[110:220,0:20,0] = 28 #
#gris_img[50:70,40:60] = 255 #realmente no es necesario especificar el plano con un único plano

#matplotlib aplica normalización entre lso valores máximo y mínimo de la imagen
#gris_img[:,:,:] = 255 #se verá negra a menos que se especifiquen vmin y vmax

#Muestra la imagen con matplotlib
#Al ser un plano, al visualizar, recordar especificar que el mapa de color usado es de grises
plt.imshow(gris_img, cmap='gray') #Prueba sin especificar el mapa de color
#plt.imshow(gris_img, cmap='gray',vmin=0, vmax=255) #evita el efecto de la normalización de matplotlib
plt.show()

# %% [markdown]
# **TAREA**: Sin herramientas de IA, crea una imagen, p.e. de 800x800 píxeles, con la textura del tablero de ajedrez.
# Una vez resuelto de forma manual, resuelve la misma tarea usando un asistente de IA de tu elección (Claude, ChatGPT, Copilot, etc.). Compara ambas versiones en el informe de la práctica.

# %% [markdown]
# Imagen en color

# %%
#Crea una imagen con tres planos
color_img = np.zeros((alto,ancho,3), dtype = np.uint8)
#Dimensiones
print(color_img.shape)
#Visualiza con matplotlib (sin especificar el mapa de color gris)
plt.imshow(color_img) 
plt.show()
# Out:
# (200, 300, 3)

# %%
#Modifica el primer plano de color (Rojo, ya que es RGB)
color_img[:,:,0] = 255 
#color_img[:,:,1] = 200 #Prueba otras combinaciones
#color_img[:,:,2] = 255 
plt.imshow(color_img) 
plt.show()

# %% [markdown]
# Funciones de dibujo.
# OpenCV dispone de funciones específicas para dibujar formas básicas (más información https://docs.opencv.org/4.x/dc/da5/tutorial_py_drawing_functions.html )

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

ancho = 800
alto = 800
color_img = np.zeros((alto, ancho, 3), dtype=np.uint8)
des_x = 0
des_y = 0
fila = 0
columna = 0
while des_y < alto:
    # Alternamos dependiendo de la fila y la columna
    if (fila + columna) % 2 == 0:
        color = (255, 255, 255)  # Blanco
    else:
        color = (0, 0, 0)        # Negro
    # Dibujamos el cuadrado
    cv2.rectangle(
        color_img,
        (des_x, des_y),
        (des_x + 100, des_y + 100),
        color,
        -1
    )
    # Siguiente columna
    des_x += 100
    columna += 1
    # Si llegamos al final de la fila
    if des_x >= ancho:
        des_x = 0
        des_y += 100
        # Pasamos a la siguiente fila
        fila += 1
        columna = 0
# Mostrar imagen
plt.imshow(color_img)
plt.show()
# Guardar imagen
cv2.imwrite('imagen.jpg', color_img)

#RESPUESTA DE IA ###########################################################

patron_base = np.array([[255,0],[0,255]], dtype=np.uint8)
bloque_2x2 = np.kron(patron_base, np.ones((100,100), dtype=np.uint8))
tablero_ia = np.tile(bloque_2x2, (4, 4))

plt.imshow(tablero_ia, cmap='gray')
plt.show
# Out:
# True

# %% [markdown]
# **TAREA**: Crear una imagen estilo Mondrian (un ejemplo https://www3.gobiernodecanarias.org/medusa/ecoescuela/sa/2017/04/17/descubriendo-a-mondrian/) con las funciones de dibujo de OpenCV.
# No hagas uso de herramientas de IA, parte del ejemplo anterior.

# %% [markdown]
# Abrir imagen almacenada en disco

# %%
ancho = 800
alto = 800

color_img = np.zeros((alto, ancho, 3), dtype=np.uint8)

verde = (0, 255, 0)
naranja = (0, 165, 255)
morado = (128, 0, 128)
blanco = (255, 255, 255)

color_img[0:200, 0:150] = verde
color_img[220:500, 0:150] = morado
color_img[520:800, 0:150] = naranja

color_img[0:200, 170:350] = naranja
color_img[220:450, 170:350] = blanco
color_img[470:650, 170:600] = verde
color_img[670:800, 170:400] = morado

color_img[0:180, 370:650] = morado
color_img[200:450, 370:500] = naranja
color_img[200:450, 520:800] = verde

color_img[0:180, 670:800] = verde
color_img[200:600, 650:800] = blanco
color_img[620:800, 430:620] = naranja

color_img[670:800, 640:800] = morado

print(color_img.shape)

plt.imshow(color_img)
plt.show()
# Out:
# (800, 800, 3)

# %% [markdown]
# Abre un archivo de vídeo

# %%
# Abre vídeo
vid = cv2.VideoCapture('VermeerFun.mp4') 
  
# En caso de estar abierto
if vid.isOpened():
    while(True):      
        # fotograma a fotograma
        ret, frame = vid.read()

        # Hay nuevo fotograma
        if ret:  
            # Muestra fotograma
            cv2.imshow('Vid', frame)
        
        # Detenemos pulsado ESC
        if cv2.waitKey(20) == 27:
            break
    
    # Libera el objeto de captura
    vid.release()
    # Destruye ventanas
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 16
#      12             # Muestra fotograma
#      13             cv2.imshow('Vid', frame)
#      14
#      15         # Detenemos pulsado ESC
# ---> 16         if cv2.waitKey(20) == 27:
#      17             break
#      18
#      19     # Libera el objeto de captura
#
# KeyboardInterrupt:

# %% [markdown]
# Muestra entrada de la cámara

# %%
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()
  
    # Hay nuevo fotograma
    if ret:  
        # Muestra fotograma
        cv2.imshow('Vid', frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 13
#       9         # Muestra fotograma
#      10         cv2.imshow('Vid', frame)
#      11
#      12     # Detenemos pulsado ESC
# ---> 13     if cv2.waitKey(20) == 27:
#      14         break
#      15
#      16 # Libera el objeto de captura
#
# KeyboardInterrupt:

# %% [markdown]
# Separa los tres planos de la imagen captada por la webcam y muestra en horizontal

# %%
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:
        #Separamos canales
        b = frame[:,:,0]
        g = frame[:,:,1]
        r = frame[:,:,2]
        #Dimensiones imagen de entrada
        h, w, c = frame.shape

        #Concateamos en horizontal los tres planos del fotograma
        collage = np.hstack((r, g, b))
    
        # Muestra fotograma redimensionando a la mitad para que quepa en pantalla
        cv2.imshow('RGB', cv2.resize(collage, (int(w*1.5),int(h/2)),cv2.INTER_NEAREST))
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 22
#      18         # Muestra fotograma redimensionando a la mitad para que quepa en pantalla
#      19         cv2.imshow('RGB', cv2.resize(collage, (int(w*1.5),int(h/2)),cv2.INTER_NEAREST))
#      20
#      21     # Detenemos pulsado ESC
# ---> 22     if cv2.waitKey(20) == 27:
#      23         break
#      24
#      25 # Libera el objeto de captura
#
# KeyboardInterrupt:
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %% [markdown]
# Evento de ratón para mostrar el valor RGB del píxel

# %%
# Función que trata eventos de ratón 
def mouse_events(event, x, y, flags, params):
    global px, py, R, G, B
    px = -1
    # Movimiento del puntero     
    if event==cv2.EVENT_MOUSEMOVE:
        #Valores del píxel, desde la webcam no es BGR
        B = frame[y, x, 0]
        G = frame[y, x, 1]
        R = frame[y, x, 2]  
        # Almacena valores del evento
        px = x
        py = y

# %%
vid = cv2.VideoCapture(0)

# Tipografía para mostrar texto
font = cv2.FONT_HERSHEY_SIMPLEX
  
lanzado = 0 #bandera para primer fotograma
px = -1
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret: 
        # Activa el manejador en el primer fotograma
        if lanzado == 0:
            # Muestra fotograma
            cv2.imshow('Cam', frame)   
            # Define el nombre del manejador del evento
            cv2.setMouseCallback('Cam', mouse_events)
            lanzado = 1
            
        # Muestra valores RGB intentando centrar en el puntero
        if px > -1:
            cv2.putText(frame, '{}'.format(R), (px-45,py-5), font, 0.5, (0, 0, 255), 1)
            cv2.putText(frame, '     {}'.format(G), (px-54,py-5), font, 0.5, (0, 255, 0), 1)
            cv2.putText(frame, '         {}'.format(B), (px-54,py-5), font, 0.5, (255, 0, 0), 1)
            
        cv2.imshow('Cam', frame)   
        
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 30
#      26
#      27         cv2.imshow('Cam', frame)
#      28
#      29     # Detenemos pulsado ESC
# ---> 30     if cv2.waitKey(20) == 27:
#      31         break
#      32
#      33 # Libera el objeto de captura
#
# KeyboardInterrupt:

# %% [markdown]
# **TAREA**:
# Pintar círculos en las posiciones del píxel más claro y oscuro de cada fotograma captado por la cámara. ¿Funciona de forma fluida o a saltos? En el segundo caso, ¿podrías acelerarlo?
# Si haces uso de herramientas de IA, incluye la conversación.

# %%
import cv2
import numpy as np

vid = cv2.VideoCapture(0)

while(True):

    # Capturamos un fotograma
    ret, frame = vid.read()

    if ret:

        # Convertimos el fotograma a escala de grises
        gris = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Buscamos el píxel más oscuro y el más claro
        minimo, maximo, posicion_min, posicion_max = cv2.minMaxLoc(gris)

        # Dibujamos un círculo en el píxel más oscuro
        cv2.circle(
            frame,
            posicion_min,
            10,
            (255, 0, 0),
            2
        )

        # Dibujamos un círculo en el píxel más claro
        cv2.circle(
            frame,
            posicion_max,
            10,
            (0, 0, 255),
            2
        )

        # Mostramos el fotograma
        cv2.imshow('Cam', frame)

    # Detenemos pulsando ESC
    if cv2.waitKey(20) == 27:
        break

# Liberamos la cámara
vid.release()

# Destruimos las ventanas
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 41
#      37         # Mostramos el fotograma
#      38         cv2.imshow('Cam', frame)
#      39
#      40     # Detenemos pulsando ESC
# ---> 41     if cv2.waitKey(20) == 27:
#      42         break
#      43
#      44 # Liberamos la cámara
#
# KeyboardInterrupt:

# %% [markdown]
# Pop art
# Salida de la webcam "inspirada" en Andy Warhol (Marilyn, https://temasycomentariosartepaeg.blogspot.com/p/autor-andy-warhol-1928-1987-titulo.html)

# %%
vid = cv2.VideoCapture(0)

#Dimensiones de la cámara
w = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))

#Fuerzo a mitad de resolución para ocupar menos pantalla
w=int(w/2)
h=int(h/2)
vid.set(cv2.CAP_PROP_FRAME_WIDTH, w) #En Mac no reacciona a estos comandos
vid.set(cv2.CAP_PROP_FRAME_HEIGHT, h)

#Imagen conjunta 2x original
collage = np.zeros((h*2,w*2,3), dtype = np.uint8)
tl = collage[0:h,0:w]
tr = collage[0:h,w:w+w]
bl = collage[h:h+h,0:w]
br = collage[h:h+h,w:w+w]

while True:      
    # fotograma a fotograma
    ret, frameIN = vid.read()

    #Menor tamaño
    frame = cv2.resize(frameIN, (int(w),int(h)),cv2.INTER_NEAREST)

    if ret:
        #Separamos canales
        r = frame[:,:,2]
        g = frame[:,:,1]
        b = frame[:,:,0]

        #Jugamos con los valores de los planos
        tl[:,:,0] = b
        tl[:,:,1] = g
        tl[:,:,2] = r

        tr[:,:,0] = 255 - r
        tr[:,:,1] = g
        tr[:,:,2] = b
        
        bl[:,:,0] = r
        bl[:,:,1] = 255 - b
        bl[:,:,2] = g

        br[:,:,0] = b
        br[:,:,1] = g
        br[:,:,2] = 255 - r
    
        # Muestra composición
        cv2.imshow('Cam', collage)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 54
#      50         # Muestra composición
#      51         cv2.imshow('Cam', collage)
#      52
#      53     # Detenemos pulsado ESC
# ---> 54     if cv2.waitKey(20) == 27:
#      55         break
#      56
#      57 # Libera el objeto de captura
#
# KeyboardInterrupt:

# %% [markdown]
# Transformando la imagen capturada en una colección de círculos, cuyo radio depende de la intensidad promedio de la zona

# %%
vid = cv2.VideoCapture(0)

# Se define el número de celdas
ncells = 10
off = int(ncells/2)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:
        #Dimensiones originales
        h, w, c = frame.shape
        #Redimensiono teniendo en cuenta ncells
        down_frame = cv2.resize(frame, (int(w/ncells),int(h/ncells)),cv2.INTER_NEAREST)
        #Dimensiones reducidas
        h2, w2, c2 = down_frame.shape

        #Separamos canales
        r = down_frame[:,:,0]
        g = down_frame[:,:,1]
        b = down_frame[:,:,2]

        # Creamos imagen negra
        gris_up_frame = np.zeros((h2*ncells,w2*ncells,1), dtype = np.uint8)

        # recorre valores de la imagen reducida
        for y in range(0,h2):
            for x in range(0,w2):
                # La suma de los valores RGB define el radio del círculo
                rad = int ( (r[y,x] + g[y,x] + b[y,x])/(ncells*3*2))
                cv2.circle(gris_up_frame,(x*ncells+off, y*ncells + off), rad, (255,255,255), -1)

    
        # Muestra fotograma resultante
        cv2.imshow('Cam', gris_up_frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# TAREA: Llevar a cabo una propuesta propia de pop art.
# Incluye fuentes consultadas.
# Si haces uso de herramientas de IA, incluye la conversación.

# %%
import cv2
import numpy as np

vid = cv2.VideoCapture(0)

# Dimensiones de la cámara
w = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Reducimos la imagen
w = int(w / 2)
h = int(h / 2)

vid.set(cv2.CAP_PROP_FRAME_WIDTH, w)
vid.set(cv2.CAP_PROP_FRAME_HEIGHT, h)

while True:

    ret, frame = vid.read()

    if ret:

        frame = cv2.resize(frame, (w, h))

        # Reducimos el número de colores
        frame = (frame // 64) * 64

        # Separamos los canales
        b = frame[:, :, 0]
        g = frame[:, :, 1]
        r = frame[:, :, 2]

        # Creamos el cuadro 2x2
        collage = np.zeros((h * 2, w * 2, 3), dtype=np.uint8)

        # Panel 1
        collage[0:h, 0:w, 0] = r
        collage[0:h, 0:w, 1] = g
        collage[0:h, 0:w, 2] = b

        # Panel 2
        collage[0:h, w:w*2, 0] = 255 - r
        collage[0:h, w:w*2, 1] = g
        collage[0:h, w:w*2, 2] = b

        # Panel 3
        collage[h:h*2, 0:w, 0] = r
        collage[h:h*2, 0:w, 1] = 255 - g
        collage[h:h*2, 0:w, 2] = b

        # Panel 4
        collage[h:h*2, w:w*2, 0] = r
        collage[h:h*2, w:w*2, 1] = g
        collage[h:h*2, w:w*2, 2] = 255 - b

        cv2.imshow('Pop Art', collage)

    if cv2.waitKey(20) == 27:
        break

vid.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 58
#      54         collage[h:h*2, w:w*2, 2] = 255 - b
#      55
#      56         cv2.imshow('Pop Art', collage)
#      57
# ---> 58     if cv2.waitKey(20) == 27:
#      59         break
#      60
#      61 vid.release()
#
# KeyboardInterrupt:
